# %%
# Import
import torch
import torch.nn as nn
import numpy as np
from tqdm.notebook import trange, tqdm
#from tqdm.auto import trange, tqdm
import h5py
import pandas as pd
import matplotlib.pyplot as plt
import wfdb
import ast
import os
from PIL import Image
import glob
# %matplotlib inline

# %%
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device count:", torch.cuda.device_count())
    print("Current device:", torch.cuda.current_device())
    print("Device name:", torch.cuda.get_device_name(0))
    x = torch.randn(2, 2).to("cuda")
    print("Tensor device:", x.device)
# Out:
# CUDA available: True
# Device count: 1
# Current device: 0
# Device name: NVIDIA GeForce RTX 3060 Ti
# Tensor device: cuda:0

# %%
set_data = 'L'  # L = large, S = small

# set seed
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)

# Training run labels— change to avoid overwriting previous runs
iter_kd   = 9   # saved as valid_score_9  in record_history/metrics.h5
iter_nokd = 8   # saved as valid_score_8  in record_history/metrics.h5

# Hyperparameters
learning_rate = 1e-3
weight_decay  = 4e-4
num_epochs    = 80
batch_size    = 32
alpha = 1
beta  = 1
T     = 3

# %% [markdown]
# ### Preprocessing

# %%
classes = ['NORM', 'MI', 'STTC', 'CD', 'HYP']

os.makedirs('data', exist_ok=True)

if set_data == 'S':
    h5_names = ['data/test_s.h5', 'data/train_s.h5']
else:
    h5_names = ['data/test_l.h5', 'data/train_l.h5']

try:
    f1 = h5py.File(h5_names[0], 'r')
    f2 = h5py.File(h5_names[1], 'r')
    print('Files exist')
    f1.close()
    f2.close()
except FileNotFoundError:

    path = '../ptb-xl-dataset/'
    sampling_rate=100

    # load and convert annotation data
    Y = pd.read_csv(path+'ptbxl_database.csv', index_col='ecg_id')
    Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))

    # Load raw signal data
    #X = load_raw_data(Y, sampling_rate, path)

    # Load scp_statements.csv for diagnostic aggregation
    agg_df = pd.read_csv(path+'scp_statements.csv', index_col=0)
    agg_df = agg_df[agg_df.diagnostic == 1]

    def aggregate_diagnostic(y_dic):
        tmp = []
        for key in y_dic.keys():
            if key in agg_df.index:
                tmp.append(agg_df.loc[key].diagnostic_class)
        return list(set(tmp))

    # Apply diagnostic superclass
    Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)

    # Split data into train and test
    test_fold = 10
    # Train
    #X_train = X[np.where(Y.strat_fold != test_fold)]
    y_train = Y[(Y.strat_fold != test_fold)].diagnostic_superclass
    # Test
    #X_test = X[np.where(Y.strat_fold == test_fold)]
    y_test = Y[Y.strat_fold == test_fold].diagnostic_superclass

    png_folder_path = r"..\output-images" + "\\"
    png_paths = sorted(glob.glob(png_folder_path + "*.png"))

    arrays_train = []
    arrays_test = []
    png_paths_test = [x for x in png_paths if int(x.split('\\')[-1].split('_')[0]) in y_test.index.tolist()]
    png_paths_train = [x for x in png_paths if int(x.split('\\')[-1].split('_')[0]) in y_train.index.tolist()]
    
    data_size = 0
    if set_data == 'S':
        data_size = 500
        print('Using small dataset...')
    elif set_data == 'L':
        data_size = len(png_paths)
        print('Using large dataset...')
    else:
        print('Error: No dataset specified')
        raise SystemExit  # Stops execution
        
    ratio = len(png_paths_test)/len(png_paths)
    print(f'Division of test data vs train data: {ratio}')
    data_size_test = int(ratio*data_size)
    data_size_train = data_size - data_size_test
    png_paths_test = png_paths_test[:data_size_test]
    png_paths_train = png_paths_train[:data_size_train]
    
    print(data_size)
    print(data_size_test)
    print(data_size_train)

    for p in png_paths_test:
        img = Image.open(p).convert("L")
        arrays_test.append(np.array(img))

    for p in png_paths_train:
        img = Image.open(p).convert("L")
        arrays_train.append(np.array(img))

    arrays_test = np.stack(arrays_test)
    arrays_train = np.stack(arrays_train)

    arrays_test = arrays_test / 255
    arrays_train = arrays_train / 255
    
    H = arrays_train.shape[1]
    arrays_test = arrays_test[:,int(0.275*H):,:]
    arrays_train = arrays_train[:,int(0.275*H):,:]
    
    y_test = y_test.iloc[0:].to_list()
    y_train = y_train.iloc[0:].to_list()

    for i in range(len(y_test)):
        lst = np.zeros(len(classes))
        z = 0
        for j in classes:
            if j in y_test[i]:
                lst[z] = 1
            z+=1
        y_test[i] = lst

    for i in range(len(y_train)):
        lst = np.zeros(len(classes))
        z = 0
        for j in classes:
            if j in y_train[i]:
                lst[z] = 1
            z+=1
        y_train[i] = lst

    y_test = np.stack(y_test)
    y_train = np.stack(y_train)

    y_test = y_test[:arrays_test.shape[0]]
    y_train = y_train[:arrays_train.shape[0]]

    with h5py.File(h5_names[0], "w") as h5f_test:
        h5f_test.create_dataset("images", data=arrays_test, compression="gzip")
        h5f_test.create_dataset("labels", data=y_test, compression='gzip')

    with h5py.File(h5_names[1], "w") as h5f_train:
        h5f_train.create_dataset("images", data=arrays_train, compression="gzip")
        h5f_train.create_dataset("labels", data=y_train, compression='gzip')

    print("Files created successfully")

    print(y_test.shape)
    print(arrays_test.shape)
    print(y_train.shape)
    print(arrays_train.shape)
    
    plt.imshow(arrays_train[0], cmap='gray')
    plt.show()
# Out:
# Files exist

# %% [markdown]
# ### Define your model

# %%
from torchvision import models

# Resnet

class Model(nn.Module):
    def __init__(self,):
        super(Model, self).__init__()
        self.kernel_size = 3
        
        # self.input_dim = (dimensions[0], dimensions[1]) #(425, 550) right now

        self.output_dim = None
        try:
            classes
            self.output_dim = len(classes)
            
        except NameError:
            self.output_dim = 5  # default value
            
        

        # initial_in_channels = 1 
        # h_dim = self.input_dim[0]
        # w_dim = self.input_dim[1]
        out_dim = self.output_dim
        
        #https://www.geeksforgeeks.org/machine-learning/ml-getting-started-with-alexnet/

        resnet = models.resnet50()
        
        original_first_layer = resnet.conv1
        resnet.conv1 = nn.Conv2d(
            in_channels=1,
            out_channels=original_first_layer.out_channels,
            kernel_size=original_first_layer.kernel_size,
            stride=original_first_layer.stride,
            padding=original_first_layer.padding,
            bias=False
        )

        num_features = resnet.fc.in_features
        resnet.fc = nn.Linear(num_features, out_dim)

        self.resnet = resnet

    def forward(self, x):
        x = x.unsqueeze(1)
        x = self.resnet(x)
        return x

# %% [markdown]
# ---
# ## Train function

# %%
def train_loop(epoch, dataloader, model, optimizer, loss_function, device):
    # model to training mode (important to correctly handle dropout or batchnorm layers)
    model.train()
    # allocation
    total_loss = 0  # accumulated loss
    n_entries = 0   # accumulated number of data points
    # progress bar def
    train_pbar = tqdm(dataloader, desc="Training Epoch {epoch:2d}".format(epoch=epoch), leave=True)
    # training loop
    for images, labels in train_pbar:
        # data to device (CPU or GPU if available)
        images, labels = images.to(device), labels.to(device)

        """
        TASK: Insert your code here. This task can be done in 5 lines of code.
        """
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()

        # Update accumulated values
        total_loss += loss.detach().cpu().numpy()
        n_entries += len(images)

        # Update progress bar
        train_pbar.set_postfix({'loss': total_loss / n_entries})
    train_pbar.close()
    return total_loss / n_entries

# %% [markdown]
# ### Knowledge Distillation

# %%
def train_loop_KD(epoch, dataloader, model, optimizer, device,  loss_function, loss_KD, alpha, beta, T):
    # model to training mode (important to correctly handle dropout or batchnorm layers)
    model.train()
    # allocation
    total_loss = 0  # accumulated loss
    n_entries = 0   # accumulated number of data points
    # progress bar def
    train_pbar = tqdm(dataloader, desc="Training Epoch {epoch:2d}".format(epoch=epoch), leave=True)
    # training loop
    for images, labels, sig_logits in train_pbar:
        # data to device (CPU or GPU if available)
        images, labels, sig_logits = images.to(device), labels.to(device), sig_logits.to(device)

        """
        TASK: Insert your code here. This task can be done in 5 lines of code.
        """
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = alpha*loss_function(outputs, labels) + beta* T**2* loss_KD(torch.sigmoid(outputs/T), torch.sigmoid(sig_logits/T))
        loss.backward()
        optimizer.step()

        # Update accumulated values
        total_loss += loss.detach().cpu().numpy()
        n_entries += len(images)

        # Update progress bar
        train_pbar.set_postfix({'loss': total_loss / n_entries})
    train_pbar.close()
    return total_loss / n_entries

# %%
def eval_loop_KD(epoch, dataloader, model, loss_function, device):
    # model to evaluation mode (important to correctly handle dropout or batchnorm layers)
    model.eval()
    # allocation
    total_loss = 0  # accumulated loss
    n_entries = 0   # accumulated number of data points
    valid_probs = []  # accumulated predicted probabilities
    valid_true = [] # accumulated true labels

    # progress bar def
    eval_pbar = tqdm(dataloader, desc="Evaluation Epoch {epoch:2d}".format(epoch=epoch), leave=True)
    # evaluation loop
    for images_cpu, labels_cpu, sig_logits_cpu in eval_pbar:
        # data to device (CPU or GPU if available)
        images, labels, sig_logits = images_cpu.to(device), labels_cpu.to(device), sig_logits_cpu.to(device)

        """
        TASK: Insert your code here. This task can be done in 6 lines of code.
        """

        with torch.no_grad():
            outputs = model(images)
            loss = loss_function(outputs, labels)
            probabilities = torch.sigmoid(outputs)

        valid_probs.append(probabilities.cpu().numpy())
        valid_true.append(labels.cpu().numpy())

        # Update accumulated values
        total_loss += loss.detach().cpu().numpy()
        n_entries += len(images)

        # Update progress bar
        eval_pbar.set_postfix({'loss': total_loss / n_entries})
    eval_pbar.close()
    return total_loss / n_entries, np.vstack(valid_probs), np.vstack(valid_true)

# %% [markdown]
# ---
# ## Eval function

# %%
def eval_loop(epoch, dataloader, model, loss_function, device):
    # model to evaluation mode (important to correctly handle dropout or batchnorm layers)
    model.eval()
    # allocation
    total_loss = 0  # accumulated loss
    n_entries = 0   # accumulated number of data points
    valid_probs = []  # accumulated predicted probabilities
    valid_true = [] # accumulated true labels

    # progress bar def
    eval_pbar = tqdm(dataloader, desc="Evaluation Epoch {epoch:2d}".format(epoch=epoch), leave=True)
    # evaluation loop
    for images_cpu, labels_cpu in eval_pbar:
        # data to device (CPU or GPU if available)
        images, labels = images_cpu.to(device), labels_cpu.to(device)

        """
        TASK: Insert your code here. This task can be done in 6 lines of code.
        """

        with torch.no_grad():
            outputs = model(images)
            loss = loss_function(outputs, labels)
            probabilities = torch.sigmoid(outputs)

        valid_probs.append(probabilities.cpu().numpy())
        valid_true.append(labels.cpu().numpy())

        # Update accumulated values
        total_loss += loss.detach().cpu().numpy()
        n_entries += len(images)

        # Update progress bar
        eval_pbar.set_postfix({'loss': total_loss / n_entries})
    eval_pbar.close()
    return total_loss / n_entries, np.vstack(valid_probs), np.vstack(valid_true)

# %% [markdown]
# ---
# ## Run Training

# %%
from torch.utils.data import TensorDataset, random_split, DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tqdm.write("Use device: {device:}".format(device=device))
tqdm.write("Building data loaders...")

path_to_h5_train = "data/train_s.h5" if set_data == "S" else "data/train_l.h5"

with h5py.File(path_to_h5_train, "r") as f:
    images   = torch.tensor(f["images"][()],  dtype=torch.float32)
    labels   = torch.tensor(f["labels"][()],  dtype=torch.float32)
    if "signal_logits" in f:
        z_signal   = torch.tensor(f["signal_logits"][()], dtype=torch.float32)
        has_logits = True
        print("signal_logits loaded:", z_signal.shape)
    else:
        has_logits = False
        print("WARNING: signal_logits not found — KD training will be skipped.")

dimensions = (images.shape[1], images.shape[2])

def make_loaders(dataset):
    train_sz = int(0.8 * len(dataset))
    valid_sz = len(dataset) - train_sz
    ds_train, ds_valid = random_split(dataset, [train_sz, valid_sz])
    return (DataLoader(ds_train, batch_size=batch_size, shuffle=True),
            DataLoader(ds_valid, batch_size=batch_size, shuffle=False))

if has_logits:
    train_dataloader_kd, valid_dataloader_kd = make_loaders(
        TensorDataset(images, labels, z_signal))

train_dataloader_nokd, valid_dataloader_nokd = make_loaders(
    TensorDataset(images, labels))

tqdm.write("Done!")
# Out:
# Use device: cuda
# Building data loaders...
# signal_logits loaded: torch.Size([19600, 5])
# Done!

# %%
tqdm.write("Define loss functions...")
loss_function     = nn.BCEWithLogitsLoss()
loss_distillation = nn.BCELoss()
tqdm.write("Done!")
# Out:
# Define loss functions...
# Done!

# %% [markdown]
# ### TRAINING MODEL

# %%
import os
from sklearn.metrics import roc_auc_score

os.makedirs("record_history", exist_ok=True)
os.makedirs("models", exist_ok=True)

def run_training(using_kd, iter_val, train_dl, valid_dl):
    label = "KD" if using_kd else "No-KD"
    tqdm.write(f"")
# === Training {label} model (iter={iter_val}) ===

    _model = Model().to(device)
    _optimizer = torch.optim.Adam(_model.parameters(),
                                  lr=learning_rate, weight_decay=weight_decay)
    _lr_scheduler = None

    best_score = 0
    train_loss_all, valid_loss_all, score_list = [], [], []

    for epoch in trange(1, num_epochs + 1):
        if using_kd:
            train_loss = train_loop_KD(epoch, train_dl, _model, _optimizer,
                                       device, loss_function, loss_distillation,
                                       alpha, beta, T)
            valid_loss, y_pred, y_true = eval_loop_KD(
                epoch, valid_dl, _model, loss_function, device)
        else:
            train_loss = train_loop(epoch, train_dl, _model, _optimizer,
                                    loss_function, device)
            valid_loss, y_pred, y_true = eval_loop(
                epoch, valid_dl, _model, loss_function, device)

        train_loss_all.append(train_loss)
        valid_loss_all.append(valid_loss)
        score = roc_auc_score(y_true=y_true, y_score=y_pred, average="macro")
        score_list.append(score)

        if score > best_score:
            suffix = "" if using_kd else "_NoKD"
            torch.save({"model": _model.state_dict()},
                       f"models/image_model{suffix}_{iter_val}.pth")
            best_score = score
            save_msg = "Best model -> saved"
        else:
            save_msg = ""

        tqdm.write(f"Epoch {epoch:2d}: Train Loss {train_loss:.6f}  "
                   f"Valid Loss {valid_loss:.6f}  "
                   f"Valid Score {score:.6f}  {save_msg}")

        if _lr_scheduler:
            _lr_scheduler.step()

    with h5py.File("record_history/metrics.h5", "a") as mh5:
        for key, data in [(f"train_loss_{iter_val}", train_loss_all),
                           (f"valid_loss_{iter_val}", valid_loss_all),
                           (f"valid_score_{iter_val}", score_list)]:
            if key in mh5:
                del mh5[key]
            mh5.create_dataset(key, data=np.array(data))

    tqdm.write(f"Best {label} score: {best_score:.6f}")
    return _model


if has_logits:
    model_kd = run_training(True,  iter_kd,   train_dataloader_kd,   valid_dataloader_kd)
else:
    model_kd = None
    print("Skipped KD training — run Signal notebook Cell 43 first.")

model_nokd = run_training(False, iter_nokd, train_dataloader_nokd, valid_dataloader_nokd)

# Point model at KD result for evaluation cells below
model = model_kd if model_kd is not None else model_nokd
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]
# Training Epoch  1:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  1:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  1: Train Loss 0.163543  Valid Loss 0.015314  Valid Score 0.853406  Best model -> saved
# Training Epoch  2:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  2:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  2: Train Loss 0.152598  Valid Loss 0.012145  Valid Score 0.896908  Best model -> saved
# Training Epoch  3:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  3:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  3: Train Loss 0.148956  Valid Loss 0.019251  Valid Score 0.882933
# Training Epoch  4:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  4:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  4: Train Loss 0.147398  Valid Loss 0.009972  Valid Score 0.904985  Best model -> saved
# Training Epoch  5:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  5:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  5: Train Loss 0.146427  Valid Loss 0.017581  Valid Score 0.897019
# Training Epoch  6:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  6:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  6: Train Loss 0.145359  Valid Loss 0.022874  Valid Score 0.861748
# Training Epoch  7:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  7:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  7: Train Loss 0.144792  Valid Loss 0.020385  Valid Score 0.886280
# Training Epoch  8:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  8:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  8: Train Loss 0.144434  Valid Loss 0.073311  Valid Score 0.792813
# Training Epoch  9:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  9:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  9: Train Loss 0.143920  Valid Loss 0.015593  Valid Score 0.846502
# Training Epoch 10:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 10:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 10: Train Loss 0.143413  Valid Loss 0.011061  Valid Score 0.909223  Best model -> saved
# Training Epoch 11:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 11:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 11: Train Loss 0.143231  Valid Loss 0.013569  Valid Score 0.896849
# Training Epoch 12:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 12:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 12: Train Loss 0.142671  Valid Loss 0.014524  Valid Score 0.903438
# Training Epoch 13:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 13:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 13: Train Loss 0.142271  Valid Loss 0.010902  Valid Score 0.909860  Best model -> saved
# Training Epoch 14:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 14:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 14: Train Loss 0.141856  Valid Loss 0.014173  Valid Score 0.899662
# Training Epoch 15:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 15:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 15: Train Loss 0.141393  Valid Loss 0.045484  Valid Score 0.891491
# Training Epoch 16:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 16:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 16: Train Loss 0.141107  Valid Loss 0.012731  Valid Score 0.910297  Best model -> saved
# Training Epoch 17:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 17:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 17: Train Loss 0.140785  Valid Loss 0.029758  Valid Score 0.888792
# Training Epoch 18:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 18:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 18: Train Loss 0.140515  Valid Loss 0.012584  Valid Score 0.921287  Best model -> saved
# Training Epoch 19:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 19:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 19: Train Loss 0.139967  Valid Loss 0.011216  Valid Score 0.905027
# Training Epoch 20:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 20:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 20: Train Loss 0.140040  Valid Loss 0.010083  Valid Score 0.916168
# Training Epoch 21:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 21:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 21: Train Loss 0.139747  Valid Loss 0.053181  Valid Score 0.870737
# Training Epoch 22:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 22:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 22: Train Loss 0.139444  Valid Loss 0.013460  Valid Score 0.894170
# Training Epoch 23:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 23:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 23: Train Loss 0.138991  Valid Loss 0.010722  Valid Score 0.910047
# Training Epoch 24:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 24:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 24: Train Loss 0.139103  Valid Loss 0.016268  Valid Score 0.886441
# Training Epoch 25:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 25:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 25: Train Loss 0.138730  Valid Loss 0.044596  Valid Score 0.825823
# Training Epoch 26:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 26:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 26: Train Loss 0.138483  Valid Loss 0.083239  Valid Score 0.823015
# Training Epoch 27:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 27:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 27: Train Loss 0.138501  Valid Loss 0.030323  Valid Score 0.880379
# Training Epoch 28:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 28:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 28: Train Loss 0.138133  Valid Loss 0.012042  Valid Score 0.903579
# Training Epoch 29:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 29:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 29: Train Loss 0.138017  Valid Loss 0.015096  Valid Score 0.907637
# Training Epoch 30:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 30:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 30: Train Loss 0.137974  Valid Loss 0.009609  Valid Score 0.920322
# Training Epoch 31:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 31:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 31: Train Loss 0.137720  Valid Loss 0.010287  Valid Score 0.908845
# Training Epoch 32:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 32:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 32: Train Loss 0.137649  Valid Loss 0.032395  Valid Score 0.885157
# Training Epoch 33:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 33:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 33: Train Loss 0.137549  Valid Loss 0.041410  Valid Score 0.854825
# Training Epoch 34:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 34:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 34: Train Loss 0.137485  Valid Loss 0.107182  Valid Score 0.819895
# Training Epoch 35:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 35:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 35: Train Loss 0.137587  Valid Loss 0.020364  Valid Score 0.909741
# Training Epoch 36:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 36:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 36: Train Loss 0.137026  Valid Loss 0.012209  Valid Score 0.920489
# Training Epoch 37:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 37:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 37: Train Loss 0.137103  Valid Loss 0.010357  Valid Score 0.913640
# Training Epoch 38:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 38:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 38: Train Loss 0.137154  Valid Loss 0.012025  Valid Score 0.914497
# Training Epoch 39:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 39:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 39: Train Loss 0.136982  Valid Loss 0.009799  Valid Score 0.914274
# Training Epoch 40:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 40:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 40: Train Loss 0.136923  Valid Loss 0.010534  Valid Score 0.909503
# Training Epoch 41:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 41:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 41: Train Loss 0.136933  Valid Loss 0.012853  Valid Score 0.911115
# Training Epoch 42:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 42:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 42: Train Loss 0.136745  Valid Loss 0.014037  Valid Score 0.906942
# Training Epoch 43:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 43:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 43: Train Loss 0.136653  Valid Loss 0.030499  Valid Score 0.893111
# Training Epoch 44:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 44:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 44: Train Loss 0.136702  Valid Loss 0.009422  Valid Score 0.918662
# Training Epoch 45:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 45:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 45: Train Loss 0.136648  Valid Loss 0.020056  Valid Score 0.896528
# Training Epoch 46:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 46:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 46: Train Loss 0.136545  Valid Loss 0.024564  Valid Score 0.890973
# Training Epoch 47:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 47:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 47: Train Loss 0.136547  Valid Loss 0.013822  Valid Score 0.894414
# Training Epoch 48:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 48:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 48: Train Loss 0.136359  Valid Loss 0.013798  Valid Score 0.905420
# Training Epoch 49:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 49:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 49: Train Loss 0.136282  Valid Loss 0.033678  Valid Score 0.881082
# Training Epoch 50:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 50:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 50: Train Loss 0.136439  Valid Loss 0.011235  Valid Score 0.897989
# Training Epoch 51:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 51:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 51: Train Loss 0.136298  Valid Loss 0.021316  Valid Score 0.897112
# Training Epoch 52:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 52:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 52: Train Loss 0.136397  Valid Loss 0.027917  Valid Score 0.890242
# Training Epoch 53:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 53:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 53: Train Loss 0.136377  Valid Loss 0.009898  Valid Score 0.913238
# Training Epoch 54:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 54:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 54: Train Loss 0.136277  Valid Loss 0.023606  Valid Score 0.873126
# Training Epoch 55:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 55:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 55: Train Loss 0.136202  Valid Loss 0.015560  Valid Score 0.902163
# Training Epoch 56:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 56:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 56: Train Loss 0.135975  Valid Loss 0.009279  Valid Score 0.925284  Best model -> saved
# Training Epoch 57:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 57:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 57: Train Loss 0.135939  Valid Loss 0.020414  Valid Score 0.892164
# Training Epoch 58:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 58:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 58: Train Loss 0.135996  Valid Loss 0.015805  Valid Score 0.886933
# Training Epoch 59:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 59:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 59: Train Loss 0.136135  Valid Loss 0.015966  Valid Score 0.892662
# Training Epoch 60:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 60:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 60: Train Loss 0.135923  Valid Loss 0.020504  Valid Score 0.879201
# Training Epoch 61:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 61:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 61: Train Loss 0.135984  Valid Loss 0.011856  Valid Score 0.912024
# Training Epoch 62:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 62:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 62: Train Loss 0.135955  Valid Loss 0.086808  Valid Score 0.794837
# Training Epoch 63:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 63:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 63: Train Loss 0.135794  Valid Loss 0.010730  Valid Score 0.908283
# Training Epoch 64:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 64:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 64: Train Loss 0.135890  Valid Loss 0.051450  Valid Score 0.870328
# Training Epoch 65:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 65:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 65: Train Loss 0.135948  Valid Loss 0.016434  Valid Score 0.902437
# Training Epoch 66:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 66:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 66: Train Loss 0.135827  Valid Loss 0.013081  Valid Score 0.908590
# Training Epoch 67:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 67:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 67: Train Loss 0.135955  Valid Loss 0.011875  Valid Score 0.907390
# Training Epoch 68:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 68:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 68: Train Loss 0.135855  Valid Loss 0.013352  Valid Score 0.910108
# Training Epoch 69:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 69:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 69: Train Loss 0.135720  Valid Loss 0.011373  Valid Score 0.911819
# Training Epoch 70:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 70:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 70: Train Loss 0.135678  Valid Loss 0.010757  Valid Score 0.911233
# Training Epoch 71:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 71:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 71: Train Loss 0.135742  Valid Loss 0.014255  Valid Score 0.911434
# Training Epoch 72:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 72:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 72: Train Loss 0.135739  Valid Loss 0.011121  Valid Score 0.904652
# Training Epoch 73:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 73:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 73: Train Loss 0.135753  Valid Loss 0.019443  Valid Score 0.875229
# Training Epoch 74:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 74:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 74: Train Loss 0.135670  Valid Loss 0.031655  Valid Score 0.891755
# Training Epoch 75:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 75:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 75: Train Loss 0.135711  Valid Loss 0.011459  Valid Score 0.906722
# Training Epoch 76:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 76:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 76: Train Loss 0.135693  Valid Loss 0.012262  Valid Score 0.896367
# Training Epoch 77:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 77:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 77: Train Loss 0.135584  Valid Loss 0.011869  Valid Score 0.914054
# Training Epoch 78:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 78:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 78: Train Loss 0.135626  Valid Loss 0.019367  Valid Score 0.884987
# Training Epoch 79:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 79:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 79: Train Loss 0.135780  Valid Loss 0.013773  Valid Score 0.902673
# Training Epoch 80:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 80:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 80: Train Loss 0.135719  Valid Loss 0.012993  Valid Score 0.891199
# Best KD score: 0.925284
#   0%|          | 0/80 [00:00<?, ?it/s]
# Training Epoch  1:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  1:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  1: Train Loss 0.013268  Valid Loss 0.013882  Valid Score 0.853912  Best model -> saved
# Training Epoch  2:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  2:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  2: Train Loss 0.011348  Valid Loss 0.013655  Valid Score 0.871261  Best model -> saved
# Training Epoch  3:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  3:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  3: Train Loss 0.010692  Valid Loss 0.043494  Valid Score 0.807569
# Training Epoch  4:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  4:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  4: Train Loss 0.010438  Valid Loss 0.011852  Valid Score 0.889501  Best model -> saved
# Training Epoch  5:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  5:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  5: Train Loss 0.010151  Valid Loss 0.011606  Valid Score 0.880742
# Training Epoch  6:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  6:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  6: Train Loss 0.009838  Valid Loss 0.011897  Valid Score 0.869381
# Training Epoch  7:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  7:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  7: Train Loss 0.009683  Valid Loss 0.012356  Valid Score 0.880712
# Training Epoch  8:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  8:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  8: Train Loss 0.009527  Valid Loss 0.080736  Valid Score 0.835017
# Training Epoch  9:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch  9:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch  9: Train Loss 0.009319  Valid Loss 0.011997  Valid Score 0.875607
# Training Epoch 10:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 10:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 10: Train Loss 0.009216  Valid Loss 0.011423  Valid Score 0.888083
# Training Epoch 11:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 11:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 11: Train Loss 0.009073  Valid Loss 0.031986  Valid Score 0.803681
# Training Epoch 12:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 12:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 12: Train Loss 0.008969  Valid Loss 0.024268  Valid Score 0.850963
# Training Epoch 13:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 13:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 13: Train Loss 0.008869  Valid Loss 0.011579  Valid Score 0.889874  Best model -> saved
# Training Epoch 14:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 14:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 14: Train Loss 0.008718  Valid Loss 0.018814  Valid Score 0.877921
# Training Epoch 15:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 15:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 15: Train Loss 0.008662  Valid Loss 0.018721  Valid Score 0.869584
# Training Epoch 16:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 16:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 16: Train Loss 0.008490  Valid Loss 0.016655  Valid Score 0.873509
# Training Epoch 17:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 17:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 17: Train Loss 0.008356  Valid Loss 0.066072  Valid Score 0.748870
# Training Epoch 18:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 18:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 18: Train Loss 0.008338  Valid Loss 0.018246  Valid Score 0.871566
# Training Epoch 19:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 19:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 19: Train Loss 0.008237  Valid Loss 0.026158  Valid Score 0.871024
# Training Epoch 20:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 20:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 20: Train Loss 0.008098  Valid Loss 0.024331  Valid Score 0.836252
# Training Epoch 21:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 21:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 21: Train Loss 0.007983  Valid Loss 0.067268  Valid Score 0.775455
# Training Epoch 22:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 22:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 22: Train Loss 0.007985  Valid Loss 0.032547  Valid Score 0.853366
# Training Epoch 23:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 23:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 23: Train Loss 0.007867  Valid Loss 0.037030  Valid Score 0.798842
# Training Epoch 24:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 24:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 24: Train Loss 0.007745  Valid Loss 0.042211  Valid Score 0.747604
# Training Epoch 25:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 25:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 25: Train Loss 0.007678  Valid Loss 0.013448  Valid Score 0.891802  Best model -> saved
# Training Epoch 26:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 26:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 26: Train Loss 0.007633  Valid Loss 0.012736  Valid Score 0.882835
# Training Epoch 27:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 27:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 27: Train Loss 0.007521  Valid Loss 0.054332  Valid Score 0.770849
# Training Epoch 28:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 28:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 28: Train Loss 0.007326  Valid Loss 0.021204  Valid Score 0.682408
# Training Epoch 29:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 29:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 29: Train Loss 0.007393  Valid Loss 0.018105  Valid Score 0.771864
# Training Epoch 30:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 30:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 30: Train Loss 0.007258  Valid Loss 0.023347  Valid Score 0.766094
# Training Epoch 31:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 31:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 31: Train Loss 0.007198  Valid Loss 0.014571  Valid Score 0.832832
# Training Epoch 32:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 32:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 32: Train Loss 0.007137  Valid Loss 0.013813  Valid Score 0.887096
# Training Epoch 33:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 33:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 33: Train Loss 0.006947  Valid Loss 0.015248  Valid Score 0.856877
# Training Epoch 34:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 34:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 34: Train Loss 0.006981  Valid Loss 0.012489  Valid Score 0.857570
# Training Epoch 35:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 35:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 35: Train Loss 0.006911  Valid Loss 0.017770  Valid Score 0.887111
# Training Epoch 36:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 36:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 36: Train Loss 0.006784  Valid Loss 0.023217  Valid Score 0.842736
# Training Epoch 37:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 37:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 37: Train Loss 0.006693  Valid Loss 0.012819  Valid Score 0.890090
# Training Epoch 38:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 38:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 38: Train Loss 0.006658  Valid Loss 0.011992  Valid Score 0.856803
# Training Epoch 39:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 39:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 39: Train Loss 0.006565  Valid Loss 0.021989  Valid Score 0.861092
# Training Epoch 40:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 40:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 40: Train Loss 0.006557  Valid Loss 0.045302  Valid Score 0.804000
# Training Epoch 41:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 41:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 41: Train Loss 0.006492  Valid Loss 0.027889  Valid Score 0.874103
# Training Epoch 42:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 42:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 42: Train Loss 0.006350  Valid Loss 0.014530  Valid Score 0.877561
# Training Epoch 43:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 43:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 43: Train Loss 0.006311  Valid Loss 0.011602  Valid Score 0.867996
# Training Epoch 44:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 44:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 44: Train Loss 0.006259  Valid Loss 0.019971  Valid Score 0.855305
# Training Epoch 45:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 45:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 45: Train Loss 0.006170  Valid Loss 0.015079  Valid Score 0.864363
# Training Epoch 46:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 46:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 46: Train Loss 0.006123  Valid Loss 0.018763  Valid Score 0.874972
# Training Epoch 47:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 47:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 47: Train Loss 0.006090  Valid Loss 0.018021  Valid Score 0.792603
# Training Epoch 48:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 48:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 48: Train Loss 0.005981  Valid Loss 0.015107  Valid Score 0.820618
# Training Epoch 49:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 49:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 49: Train Loss 0.005906  Valid Loss 0.012550  Valid Score 0.877762
# Training Epoch 50:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 50:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 50: Train Loss 0.005880  Valid Loss 0.023020  Valid Score 0.797704
# Training Epoch 51:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 51:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 51: Train Loss 0.005877  Valid Loss 0.013970  Valid Score 0.867293
# Training Epoch 52:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 52:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 52: Train Loss 0.005779  Valid Loss 0.017248  Valid Score 0.880832
# Training Epoch 53:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 53:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 53: Train Loss 0.005796  Valid Loss 0.011173  Valid Score 0.883668
# Training Epoch 54:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 54:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 54: Train Loss 0.005684  Valid Loss 0.014067  Valid Score 0.865218
# Training Epoch 55:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 55:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 55: Train Loss 0.005725  Valid Loss 0.042119  Valid Score 0.755739
# Training Epoch 56:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 56:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 56: Train Loss 0.005611  Valid Loss 0.016864  Valid Score 0.862244
# Training Epoch 57:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 57:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 57: Train Loss 0.005535  Valid Loss 0.017906  Valid Score 0.846947
# Training Epoch 58:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 58:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 58: Train Loss 0.005572  Valid Loss 0.012293  Valid Score 0.849700
# Training Epoch 59:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 59:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 59: Train Loss 0.005466  Valid Loss 0.011032  Valid Score 0.891706
# Training Epoch 60:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 60:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 60: Train Loss 0.005474  Valid Loss 0.067927  Valid Score 0.793498
# Training Epoch 61:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 61:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 61: Train Loss 0.005513  Valid Loss 0.014195  Valid Score 0.873444
# Training Epoch 62:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 62:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 62: Train Loss 0.005340  Valid Loss 0.021968  Valid Score 0.867628
# Training Epoch 63:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 63:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 63: Train Loss 0.005275  Valid Loss 0.022344  Valid Score 0.859814
# Training Epoch 64:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 64:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 64: Train Loss 0.005307  Valid Loss 0.021719  Valid Score 0.854947
# Training Epoch 65:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 65:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 65: Train Loss 0.005221  Valid Loss 0.021221  Valid Score 0.875350
# Training Epoch 66:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 66:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 66: Train Loss 0.005248  Valid Loss 0.049992  Valid Score 0.777882
# Training Epoch 67:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 67:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 67: Train Loss 0.005107  Valid Loss 0.020168  Valid Score 0.843714
# Training Epoch 68:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 68:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 68: Train Loss 0.005180  Valid Loss 0.076758  Valid Score 0.795787
# Training Epoch 69:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 69:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 69: Train Loss 0.005126  Valid Loss 0.016475  Valid Score 0.810587
# Training Epoch 70:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 70:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 70: Train Loss 0.005156  Valid Loss 0.012933  Valid Score 0.880193
# Training Epoch 71:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 71:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 71: Train Loss 0.005074  Valid Loss 0.013203  Valid Score 0.859610
# Training Epoch 72:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 72:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 72: Train Loss 0.005071  Valid Loss 0.028499  Valid Score 0.788710
# Training Epoch 73:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 73:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 73: Train Loss 0.005017  Valid Loss 0.012310  Valid Score 0.871760
# Training Epoch 74:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 74:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 74: Train Loss 0.004931  Valid Loss 0.012746  Valid Score 0.886591
# Training Epoch 75:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 75:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 75: Train Loss 0.005069  Valid Loss 0.025825  Valid Score 0.846434
# Training Epoch 76:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 76:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 76: Train Loss 0.004905  Valid Loss 0.013794  Valid Score 0.856839
# Training Epoch 77:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 77:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 77: Train Loss 0.004904  Valid Loss 0.045493  Valid Score 0.794252
# Training Epoch 78:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 78:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 78: Train Loss 0.004981  Valid Loss 0.053719  Valid Score 0.822875
# Training Epoch 79:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 79:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 79: Train Loss 0.004790  Valid Loss 0.013340  Valid Score 0.886831
# Training Epoch 80:   0%|          | 0/490 [00:00<?, ?it/s]
# Evaluation Epoch 80:   0%|          | 0/123 [00:00<?, ?it/s]
# Epoch 80: Train Loss 0.004804  Valid Loss 0.022247  Valid Score 0.847419
# Best No-KD score: 0.891802

# %% [markdown]
# #### Save metrics

# %%
# Metrics are saved automatically inside run_training() above.
# record_history/metrics.h5 now contains entries for iter_kd and iter_nokd.

# %% [markdown]
# #### Plot

# %%
with h5py.File("record_history/metrics.h5", "r") as mh5:
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for ax, (label, it, color) in zip(
        axes,
        [(f"KD (iter={iter_kd})",    iter_kd,   "orange"),
         (f"No-KD (iter={iter_nokd})", iter_nokd, "red")]
    ):
        key = f"valid_score_{it}"
        if key not in mh5:
            ax.set_title(f"{label} — not found")
            continue
        scores = mh5[key][()]
        best_i = int(np.argmax(scores))
        ax.plot(scores, color=color, label=label)
        ax.plot(best_i, scores[best_i], "ro",
                label=f"Best: {scores[best_i]:.4f} @ epoch {best_i}")
        ax.set_title(f"Validation AUROC — {label}")
        ax.set_xlabel("Epoch")
        ax.set_ylabel("Macro AUROC")
        ax.legend()
        ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Model Testing

# %%
from torch.utils.data import TensorDataset, random_split, DataLoader
import matplotlib.pyplot as plt

# build the dataloader once and re-use when running the cell below possibly multiple times.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# =============== Build data loaders ==========================================#
tqdm.write("Building data loaders...")
# load data
if set_data == 'S':
    path_to_h5_test = 'data/test_s.h5'
else:
    path_to_h5_test = 'data/test_l.h5'




images_test = torch.tensor(h5py.File(path_to_h5_test, 'r')['images'][()], dtype=torch.float32)
labels_test = torch.tensor(h5py.File(path_to_h5_test, 'r')['labels'][()], dtype=torch.float32)
dataset_test = TensorDataset(images_test, labels_test)
len_dataset_test = len(dataset_test)
print(images_test.shape)
# build data loaders
test_dataloader = DataLoader(dataset_test, batch_size=32, shuffle=False)
tqdm.write("Done!\n")



# images_train = torch.tensor(h5py.File('train_50.h5', 'r')['images'][()], dtype=torch.float32)#247
# print(images_train.shape)
# plt.imshow(images_test[5,:,:].squeeze(), cmap="gray")
# print(((images_train[:,:,:]).max()))
# Out:
# Building data loaders...
# torch.Size([2198, 185, 330])
# Done!

# %%
# =============== Select iteration to test ================================================#

iter=8

# =============== Define model ================================================#
tqdm.write("Define model...")
"""
TASK: Replace the baseline model with your model; Insert your code here
"""

model = Model()


kd=["_NoKD",""]
path_model = f'models/image_model{kd[0]}_{iter}.pth'
# load stored model parameters
ckpt = torch.load(path_model, map_location=lambda storage, loc: storage)
model.load_state_dict(ckpt['model'])
# put model on device
model.to(device=device)
tqdm.write("Done!\n")

# =============== Evaluate on test ==============================================#
model.eval()
# allocation
test_pred = torch.zeros(len_dataset_test,len(classes))
test_true = torch.zeros(len_dataset_test,len(classes))
# progress bar def
test_pbar = tqdm(test_dataloader, desc="Testing")

# evaluation loop
end=0
for traces in test_pbar:
    # data to device
    labels = traces[1].to(device)
    traces = traces[0].to(device)
    start = end

    with torch.no_grad():
        # Forward pass
        model_output = model(traces)

        # store output
        end = min(start + len(model_output), test_pred.shape[0])
        test_pred[start:end] = torch.nn.Sigmoid()(model_output).detach().cpu()
        test_true[start:end] = labels

test_pbar.close()

# =============== Evaluate on validation ==============================================#
model.eval()
# allocation
valid_pred = torch.zeros(len(valid_dataloader_nokd.dataset),len(classes))
valid_true = torch.zeros(len(valid_dataloader_nokd.dataset),len(classes))

# progress bar def
valid_pbar = tqdm(valid_dataloader_nokd, desc="Validating")

# evaluation loop
end=0
for traces in valid_pbar:
    # data to device
    labels = traces[1].to(device)
    traces = traces[0].to(device)
    start = end
    
    with torch.no_grad():
        # Forward pass
        model_output = model(traces)

        # store output
        end = min(start + len(model_output), valid_pred.shape[0])
        valid_pred[start:end] = torch.nn.Sigmoid()(model_output).detach().cpu()
        valid_true[start:end] = labels

valid_pbar.close()

# =============== Save predictions ============================================#
# Only binary
# soft_pred = np.stack((1-test_pred.numpy(), test_pred.numpy()),axis=1).squeeze()
# Out:
# Define model...
# Done!
# Testing:   0%|          | 0/69 [00:00<?, ?it/s]
# Validating:   0%|          | 0/123 [00:00<?, ?it/s]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, log_loss, brier_score_loss

# Predictions for validation and test
if type(test_pred)!= np.ndarray:
    test_pred = test_pred.detach().cpu().numpy()
if type(test_true)!= np.ndarray:
    test_true = test_true.detach().cpu().numpy()
if type(valid_pred)!= np.ndarray:
    valid_pred = valid_pred.detach().cpu().numpy()
if type(valid_true)!= np.ndarray:
    valid_true = valid_true.detach().cpu().numpy()

def brier_score_per_class(y_true, y_pred_proba):
    """
    Calculate Brier score for each class separately
    """
    y_true = np.asarray(y_true)
    y_pred_proba = np.asarray(y_pred_proba)
    
    n_classes = y_true.shape[1]
    scores = []
    
    for k in range(n_classes):
        score = np.mean((y_pred_proba[:, k] - y_true[:, k]) ** 2)
        scores.append(score)
    
    return np.array(scores)

loss_function = nn.BCELoss()


# Lower is better for these
lg_loss = loss_function(torch.tensor(test_pred), torch.tensor(test_true)).item()
# Also lower is better
brier = brier_score_per_class(y_true=test_true, y_pred_proba=test_pred)
# Higher is better
auc = roc_auc_score(y_true=test_true, y_score=test_pred)
print("log loss:", lg_loss, '\n' "brier score:", brier, '\n' "auroc:", auc, '\n')



# y_true and y_pred are available from the last evaluation loop on the validation set
n_classes = len(classes)
optimal_thresholds = np.zeros(n_classes)
th_list = np.linspace(0.01, 0.99, 100)

print(f'Optimal thresholds:')
for class_i in range(n_classes):
    best_f1 = 0
    best_th = 0.5
    
    for th in th_list:
        class_predictions = (valid_pred[:, class_i] >= th).astype(int)
        class_f1 = f1_score(valid_true[:, class_i], class_predictions)
        
        if class_f1 > best_f1:
            best_f1 = class_f1
            best_th = th
    
    optimal_thresholds[class_i] = best_th
    print(f'{classes[class_i]}: {best_th:.2f}')


# Predictions on Validation after Thresholds
valid_bin_pred_th= np.zeros_like(valid_true)
for class_i in range(n_classes):
    valid_bin_pred_th[:, class_i] = (valid_pred[:, class_i] >= optimal_thresholds[class_i]).astype(int)

# Calculate accuracy on Validation after Thresholds
micro_auroc = roc_auc_score(valid_true, valid_pred, average='micro')
macro_auroc = roc_auc_score(valid_true, valid_pred, average='macro')
micro_f1 = f1_score(valid_true, valid_bin_pred_th, average='micro')
macro_f1 = f1_score(valid_true, valid_bin_pred_th, average='macro')
per_class_f1 = f1_score(valid_true, valid_bin_pred_th, average=None)

print(f"\nValidation Metrics after Thresholds:")
print(f"Micro Auroc: {micro_auroc:.4f}")
print(f"Macro Auroc: {macro_auroc:.4f}")
print(f"Micro F1-score: {micro_f1:.4f}")
print(f"Macro F1-score: {macro_f1:.4f}")
print(f"Per Class F1-score: {per_class_f1}")



# for i in range(10):
#     print(f'{valid_bin_pred_th[i]} = {valid_true[i]} = {valid_pred[i]}')

# Predictions on TEST after Thresholds
test_bin_pred_th= np.zeros_like(test_true)
for class_i in range(n_classes):
    test_bin_pred_th[:, class_i] = (test_pred[:, class_i] >= optimal_thresholds[class_i]).astype(int)

# Calculate accuracy on TEST
micro_auroc_test = roc_auc_score(test_true, test_pred, average='micro')
macro_auroc_test = roc_auc_score(test_true, test_pred, average='macro')
micro_f1_test = f1_score(test_true, test_bin_pred_th, average='micro')
macro_f1_test = f1_score(test_true, test_bin_pred_th, average='macro')
per_class_f1 = f1_score(test_true, test_bin_pred_th, average=None)

print(f"\nTest Metrics after Thresholds:")
print(f"Micro Auroc: {micro_auroc_test:.4f}")
print(f"Macro Auroc: {macro_auroc_test:.4f}")
print(f"Micro F1-score: {micro_f1_test:.4f}")
print(f"Macro F1-score: {macro_f1_test:.4f}")
print(f"Per Class F1-score: {per_class_f1}")
# Out:
# log loss: 0.4424452483654022
# brier score: [0.13811295 0.1395871  0.20291755 0.12989172 0.07890873]
# auroc: 0.8761386151123688
#
# Optimal thresholds:
# NORM: 0.21
# MI: 0.12
# STTC: 0.86
# CD: 0.12
# HYP: 0.16
#
# Validation Metrics after Thresholds:
# Micro Auroc: 0.8656
# Macro Auroc: 0.8918
# Micro F1-score: 0.7251
# Macro F1-score: 0.6922
# Per Class F1-score: [0.81933702 0.71612265 0.67931873 0.68077388 0.56557377]
#
# Test Metrics after Thresholds:
# Micro Auroc: 0.8562
# Macro Auroc: 0.8761
# Micro F1-score: 0.7059
# Macro F1-score: 0.6655
# Per Class F1-score: [0.80846968 0.65047702 0.70052539 0.65016873 0.51807229]

# %% [markdown]
# #### Aditional Metrics

# %%
# Order: No KD, KD, Signal, Naive

specificity_array = np.zeros((n_classes,4))
recall_array = np.zeros((n_classes,4))
PPV_array = np.zeros((n_classes,4))
Bal_acc_array = np.zeros((n_classes,4))

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

# Predictions for validation and test
if type(test_pred)!= np.ndarray:
    test_pred = test_pred.detach().cpu().numpy()
if type(test_true)!= np.ndarray:
    test_true = test_true.detach().cpu().numpy()
if type(valid_pred)!= np.ndarray:
    valid_pred = valid_pred.detach().cpu().numpy()
if type(valid_true)!= np.ndarray:
    valid_true = valid_true.detach().cpu().numpy()

test_bin_pred = (test_pred >= 0.5).astype(int)
valid_bin_pred = (valid_pred >= 0.5).astype(int)



# with h5py.File('signal_test_s.h5', 'r') as f:
#     test_true = f['labels'][:]       # or np.array(f['labels'])



# for i in range(10):
#     print(f'{valid_bin_pred[i]} = {valid_true[i]} = {valid_pred[i]}')


# Calculate accuracy on Validation
micro_auroc = roc_auc_score(valid_true, valid_pred, average='micro')
macro_auroc = roc_auc_score(valid_true, valid_pred, average='macro')
micro_f1 = f1_score(valid_true, valid_bin_pred, average='micro')
macro_f1 = f1_score(valid_true, valid_bin_pred, average='macro')

print(f"\nValidation Metrics before Thresholds:")
print(f"Micro Auroc: {micro_auroc:.4f}")
print(f"Macro Auroc: {macro_auroc:.4f}")
print(f"Micro F1-score: {micro_f1:.4f}")
print(f"Macro F1-score: {macro_f1:.4f}")

#Calculate accuracy on Test:

# Calculate accuracy on TEST
micro_auroc_test = roc_auc_score(test_true, test_pred, average='micro')
macro_auroc_test = roc_auc_score(test_true, test_pred, average='macro')
micro_f1_test = f1_score(test_true, test_bin_pred, average='micro')
macro_f1_test = f1_score(test_true, test_bin_pred, average='macro')

print(f"\nTest Metrics before Thresholds:")
print(f"Micro Auroc: {micro_auroc_test:.4f}")
print(f"Macro Auroc: {macro_auroc_test:.4f}")
print(f"Micro F1-score: {micro_f1_test:.4f}")
print(f"Macro F1-score: {macro_f1_test:.4f}\n")


# y_true and y_pred are available from the last evaluation loop on the validation set
n_classes = len(classes)
optimal_thresholds = np.zeros(n_classes)
th_list = np.linspace(0.01, 0.99, 100)

print(f'Optimal thresholds:')
for class_i in range(n_classes):
    best_f1 = 0
    best_th = 0.5
    
    for th in th_list:
        class_predictions = (valid_pred[:, class_i] >= th).astype(int)
        class_f1 = f1_score(valid_true[:, class_i], class_predictions)
        
        if class_f1 > best_f1:
            best_f1 = class_f1
            best_th = th
    
    optimal_thresholds[class_i] = best_th
    print(f'{classes[class_i]}: {best_th:.2f}')


# Predictions on Validation after Thresholds
valid_bin_pred_th= np.zeros_like(valid_bin_pred)
for class_i in range(n_classes):
    valid_bin_pred_th[:, class_i] = (valid_pred[:, class_i] >= optimal_thresholds[class_i]).astype(int)

# Calculate accuracy on Validation after Thresholds
micro_auroc = roc_auc_score(valid_true, valid_pred, average='micro')
macro_auroc = roc_auc_score(valid_true, valid_pred, average='macro')
micro_f1 = f1_score(valid_true, valid_bin_pred_th, average='micro')
macro_f1 = f1_score(valid_true, valid_bin_pred_th, average='macro')
per_class_f1 = f1_score(valid_true, valid_bin_pred_th, average=None)

print(f"\nValidation Metrics after Thresholds:")
print(f"Micro Auroc: {micro_auroc:.4f}")
print(f"Macro Auroc: {macro_auroc:.4f}")
print(f"Micro F1-score: {micro_f1:.4f}")
print(f"Macro F1-score: {macro_f1:.4f}")
print(f"Per Class F1-score: {per_class_f1}")



# for i in range(10):
#     print(f'{valid_bin_pred_th[i]} = {valid_true[i]} = {valid_pred[i]}')

# Predictions on TEST after Thresholds
test_bin_pred_th= np.zeros_like(test_bin_pred)
for class_i in range(n_classes):
    test_bin_pred_th[:, class_i] = (test_pred[:, class_i] >= optimal_thresholds[class_i]).astype(int)

# Calculate accuracy on TEST
micro_auroc_test = roc_auc_score(test_true, test_pred, average='micro')
macro_auroc_test = roc_auc_score(test_true, test_pred, average='macro')
micro_f1_test = f1_score(test_true, test_bin_pred_th, average='micro')
macro_f1_test = f1_score(test_true, test_bin_pred_th, average='macro')
per_class_f1 = f1_score(test_true, test_bin_pred_th, average=None)

print(f"\nTest Metrics after Thresholds:")
print(f"Micro Auroc: {micro_auroc_test:.4f}")
print(f"Macro Auroc: {macro_auroc_test:.4f}")
print(f"Micro F1-score: {micro_f1_test:.4f}")
print(f"Macro F1-score: {macro_f1_test:.4f}")
print(f"Per Class F1-score: {per_class_f1}")


# Specificity and Sensitivity Calculation
from sklearn.metrics import confusion_matrix
print("\nSpecificity and Sensitivity per class on Test set:")
CM= np.zeros((n_classes,4)) # classes, TN, FP, FN, TP
for class_i in range(n_classes):
    tn, fp, fn, tp = confusion_matrix(test_true[:, class_i], test_bin_pred_th[:, class_i]).ravel()
    CM[class_i,0]= tn
    CM[class_i,1]= fp
    CM[class_i,2]= fn
    CM[class_i,3]= tp

    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    PPV = tp / (tp + fp) if (tp + fp) > 0 else 0
    NPV= tn / (tn + fn) if (tn + fn) > 0 else 0
    Balanced_acc = (recall +specificity)/2
    #vs naive metrics
    y_true = test_true[:, class_i]
    n = len(y_true)

    # majority-class naive classifier
    if np.mean(y_true) >= 0.5:
        # always predict positive
        y_pred = np.ones(n, dtype=int)
    else:
        # always predict negative
        y_pred = np.zeros(n, dtype=int)

       

    #Save in array
    k= 0 #naive, KD, NoKd, Signal
    

    specificity_array[ class_i, k] = specificity
    recall_array[ class_i, k] = recall
    PPV_array[ class_i, k] = PPV
    Bal_acc_array[ class_i, k] = Balanced_acc

os.makedirs('csv', exist_ok=True)
np.savetxt('csv/CM_test.csv', CM, delimiter=',', header='TN, FP, FN, TP', comments='')
# Out:
# Validation Metrics before Thresholds:
# Micro Auroc: 0.8656
# Macro Auroc: 0.8918
# Micro F1-score: 0.6160
# Macro F1-score: 0.5485
#
# Test Metrics before Thresholds:
# Micro Auroc: 0.8562
# Macro Auroc: 0.8761
# Micro F1-score: 0.6005
# Macro F1-score: 0.5224
#
# Optimal thresholds:
# NORM: 0.21
# MI: 0.12
# STTC: 0.86
# CD: 0.12
# HYP: 0.16
#
# Validation Metrics after Thresholds:
# Micro Auroc: 0.8656
# Macro Auroc: 0.8918
# Micro F1-score: 0.7251
# Macro F1-score: 0.6922
# Per Class F1-score: [0.81933702 0.71612265 0.67931873 0.68077388 0.56557377]
#
# Test Metrics after Thresholds:
# Micro Auroc: 0.8562
# Macro Auroc: 0.8761
# Micro F1-score: 0.7059
# Macro F1-score: 0.6655
# Per Class F1-score: [0.80846968 0.65047702 0.70052539 0.65016873 0.51807229]
#
# Specificity and Sensitivity per class on Test set:

# %%
print(f"\nSpecificity Array:\n{specificity_array}")
print(f"\nRecall Array:\n{recall_array}")
print(f"\nPPV Array:\n{PPV_array}")
print(f"\nBalanced Accuracy Array:\n{Bal_acc_array}")
# Out:
# Specificity Array:
# [[0.77732794 0.         0.         0.        ]
#  [0.86165049 0.         0.         0.        ]
#  [0.86821705 0.         0.         0.        ]
#  [0.93889542 0.         0.         0.        ]
#  [0.9447314  0.         0.         0.        ]]
#
# Recall Array:
# [[0.87227414 0.         0.         0.        ]
#  [0.68181818 0.         0.         0.        ]
#  [0.76775432 0.         0.         0.        ]
#  [0.58266129 0.         0.         0.        ]
#  [0.49236641 0.         0.         0.        ]]
#
# PPV Array:
# [[0.75336323 0.         0.         0.        ]
#  [0.62189055 0.         0.         0.        ]
#  [0.64412238 0.         0.         0.        ]
#  [0.73536896 0.         0.         0.        ]
#  [0.54661017 0.         0.         0.        ]]
#
# Balanced Accuracy Array:
# [[0.82480104 0.         0.         0.        ]
#  [0.77173433 0.         0.         0.        ]
#  [0.81798569 0.         0.         0.        ]
#  [0.76077835 0.         0.         0.        ]
#  [0.71854891 0.         0.         0.        ]]

# %%
os.makedirs("csv", exist_ok=True)
np.savetxt("csv/recall_array.csv", recall_array, delimiter=",")
np.savetxt("csv/PPV_array.csv", PPV_array, delimiter=",")
np.savetxt("csv/Bal_acc_array.csv", Bal_acc_array, delimiter=",")
np.savetxt("csv/f1_array.csv", per_class_f1, delimiter=",")
np.savetxt("csv/specificity_array.csv", specificity_array, delimiter=",")

# %% [markdown]
# ## Grad-CAM

# %%
# -----------------------------
# Grad-CAM wrapper (REQUIRED)
# -----------------------------
class GradCAMWrapper(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, x):
        # x: (N, 1, H, W)  → model expects (N, H, W)
        x = x.squeeze(1)
        return self.model(x)

# %%
import torch
import torch.nn as nn
import h5py
import numpy as np
import cv2

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Model()

image_index = 19
KD = [f"_{iter_kd}", f"_NoKD_{iter_nokd}"]

h5_path = "data/test_s.h5" if set_data == "S" else "data/test_l.h5"

for kd in KD:
    path_model = f'models/image_model{kd}.pth'

    ckpt = torch.load(path_model, map_location="cpu")
    model.load_state_dict(ckpt["model"])
    model.to(device)
    model.eval()

    wrapped_model = GradCAMWrapper(model).to(device)
    wrapped_model.eval()

    target_layers = [wrapped_model.model.resnet.layer4]

    sel_classes = [1]

    with h5py.File(h5_path, "r") as f:
        labels = f["labels"][:]
        images = f["images"]

        mask = np.any(labels[:, sel_classes] == 1, axis=1)
        indices = np.where(mask)[0]

        image = images[indices[image_index], :, :]
        label = labels[indices[image_index], :]
        pred = model(torch.tensor(image, dtype=torch.float32, device=device)[None, :, :])
        pred = torch.sigmoid(pred).detach().cpu().numpy().squeeze()

    print(f"Predicted probs {kd}:", [f"{v:.6f}" for v in pred.flatten().tolist()])

    input_tensor = torch.tensor(
        image, dtype=torch.float32, device=device
    )[None, None, :, :]

    with torch.no_grad():
        outputs = wrapped_model(input_tensor)

    class_idx = outputs.argmax(dim=1).item()

    cam = GradCAM(model=wrapped_model, target_layers=target_layers)
    targets = [ClassifierOutputTarget(class_idx)]
    grayscale_cam = cam(input_tensor=input_tensor, targets=targets)[0]

    img = image.astype(np.float32)
    img = (img - img.min()) / (img.max() - img.min() + 1e-8)
    img_rgb = np.repeat(img[:, :, None], 3, axis=2)

    cam_image = show_cam_on_image(
        img_rgb, grayscale_cam,
        colormap=cv2.COLORMAP_HOT, use_rgb=True,
    )

    os.makedirs("gradcam", exist_ok=True)
    png_save_path = "gradcam/gradcam_grayscale" + kd + ".png"
    cv2.imwrite(png_save_path, cam_image)

print("True label:", label)
# Out:
# Predicted probs _9: ['0.020661', '0.953407', '0.048580', '0.064016', '0.016050']
# Predicted probs _NoKD_8: ['0.189871', '0.362039', '0.380326', '0.116008', '0.080722']
# True label: [0. 1. 0. 0. 1.]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
metrics = ['Accuracy', 'AUROC', 'F1-Score']
models = ['No KD', 'KD', 'Signal']
model_colors = ['#1f77b4', '#2ca02c', '#d62728']  # Blue, Green, Red

# Values (transposed to group by metric)
metric_data = {
    'Accuracy': [0.8649, 0.8751, 0.8817],
    'AUROC': [0.9000, 0.9169, 0.9275],
    'F1-Score': [0.7074, 0.7286, 0.7470]
}

# Create figure
plt.figure(figsize=(10, 6))

# Set positions
x = np.arange(len(metrics))
width = 0.25
positions = [x - width, x, x + width]

# Plot bars
for i, model in enumerate(models):
    model_values = [metric_data['Accuracy'][i], 
                    metric_data['AUROC'][i], 
                    metric_data['F1-Score'][i]]
    plt.bar(positions[i], model_values, width, 
            label=model, color=model_colors[i], edgecolor='black', 
            linewidth=1, alpha=0.9)

# Formatting
plt.xlabel('Evaluation Metric', fontsize=13, fontweight='bold')
plt.ylabel('Score', fontsize=13, fontweight='bold')
plt.title('Model Performance Across Metrics', fontsize=15, fontweight='bold', pad=20)
plt.xticks(x, metrics, fontsize=12)
plt.ylim(0.65, 0.95)
plt.legend(title='Model Type', fontsize=11, title_fontsize=12, 
           framealpha=0.9, loc='upper left')
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Add value labels
for i, model in enumerate(models):
    for j, metric in enumerate(metrics):
        height = metric_data[metric][i]
        plt.text(positions[i][j], height + 0.005, f'{height:.4f}', 
                 ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()
